# %%
from google.colab import drive
drive.mount('/content/drive')
# MUST MOUNT GOOGLE DRIVE FIRST OR THE CODE WILL NOT RUN
# These are all L2 data products, may add L1 to fill holes
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pip install plotly

# %%
# Temprature Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os
import plotly.io as pio

# Default template
pio.templates.default = "plotly"



if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/A/Temp_All_CTD_Flanking_Subsurface_A1.csv')


#Lines to plot with
trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')
trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')
trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')



# Plot layout
layout = go.Layout(title={ 
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                   
                   # Change title for plot of intrest
                   title_text = 'FA Temprature vs Time',
                  plot_bgcolor='rgb(255, 255, 255)',                 
                      showlegend=True,
                     legend_orientation="h",
                   
                
                  font=dict(
                          family="Avenir, monospace",
                          size=22,
                         color="#000000"),
                         height=500,
                         width=2000,
                   
                   
                     xaxis=dict(
                         # Change title for x variable of intrest
                         title_text = 'Date',
                         tickmode = 'array',
                         ticktext = ('O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A'), 
                         tickvals=('2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01'),    
                                     
                          gridcolor= 'rgb(125, 125, 125)',
                        
                     ),
                   
                  
                 yaxis=dict(
                      # Change title for y variable of intrest
                     title_text = 'Temperature (°C)',
                        tickmode = 'array',
                        range=[3,10],
                        tickvals = ('3','4','5','6','7','8','9','10'),
                        gridcolor= 'rgb(125, 125, 125)', 
                              
                     
                        
               title_standoff = 0          

               ),
          
            
)
                   



#Change to trace amount
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)


# Change to years specific to data useing
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2015-01-01',
            y0=0,
            x1='2015-01-01',
            y1=10,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2016-01-01',
            y0=0,
            x1='2016-01-01',
            y1=10,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2017-01-01',
            y0=0,
            x1='2017-01-01',
            y1=10,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2018-01-01',
            y0=0,
            x1='2018-01-01',
            y1=10,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2019-01-01',
            y0=0,
            x1='2019-01-01',
            y1=10,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))



# Adds rectangle around plot, change values specific to your data

fig.add_shape(
        # unfilled Rectangle
            type="rect",
            x0='2014-09-12',
            y0=3.06,
            x1='2019-08-09',
            y1=9.94,
            line=dict(
                 color="rgb(100, 100, 100)",
                 width=6.5
            ),)


# Makes legend item size larger
fig.update_layout(legend= {'itemsizing': 'constant'})


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3ba25b55-ec8d-4b66-9d3f-cb9e15eb0def" class="plotly-graph-div" style="height:500px; width:2000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3ba25b55-ec8d-4b66-9d3f-cb9e15eb0def")) {
#                     Plotly.newPlot(
#                         '3ba25b55-ec8d-4b66-9d3f-cb9e15eb0def',
# ...

# %%
library(plotly)
ax <- list(
  zeroline = TRUE,
  showline = TRUE,
  mirror = "ticks",
  gridcolor = toRGB("gray50"),
  gridwidth = 2,
  zerolinecolor = toRGB("red"),
  zerolinewidth = 4,
  linecolor = toRGB("black"),
  linewidth = 6
)
s <- seq(-1, 4)
fig <- plot_ly(x = ~s, y = ~s)
fig <- fig %>% layout(xaxis = ax, yaxis = ax)

fig
# Out:
#   File "<ipython-input-44-e9c95528aca0>", line 15
#     fig <- fig %>% layout(xaxis = ax, yaxis = ax)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
#  #tickvals=(19, 50, 80, \
#                                    110, 142, 170, 201, 231, 262, 291, 323, 354, 384, 415, 445, \
#                                    476, 507, 536, 567, 597, 628, 658, 694, 725, 755, 786, 816, \
#                                    847, 878, 906, 937, 967, 998, 1028, 1059, 1095, 1125, 1156, 1186, \
#                                    1217, 1248, 1276, 1307, 1337, 1368, 1404, 1435, 1466, 1496, 1527, 1557, \
#                                    1588, 1619, 1647, 1678, 1708, 1739, 1769, 1800),

# %%
 #tickvals=(.

# %%
# Density Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os
import plotly.io as pio

# Default template
pio.templates.default = "plotly"

if not os.path.exists("images"):
    os.mkdir("images")

df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/A/Denisty_All_CTD_Flanking_Subsurface_A1.csv')

#Lines to plot with
trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')
trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')
trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')

# Plot layout
layout = go.Layout(title={ 
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                   
                   # Change title for plot of intrest
                   title_text = 'FA Density vs Time',
                 plot_bgcolor='rgb(255, 255, 255)',                 
                      showlegend=True,
                     legend_orientation="h",
                   
                
                  font=dict(
                          family="Avenir, monospace",
                          size=22,
                         color="#000000"),
                         height=500,
                         width=2000,
                   

                 xaxis=dict(
                         # Change title for x variable of intrest
                         title_text = 'Date',
                         tickmode = 'array',
                         ticktext = ('O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A'), 
                         tickvals=('2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01'),    
                                     
                          gridcolor= 'rgb(125, 125, 125)',
                        
                     ),
                   
                 yaxis=dict(
                      # Change title for y variable of intrest
                     title_text = 'Density (kg m-3)',
                        tickmode = 'array',                       
                        range=[1029.5,1026.5] ,
                        tickvals = ('1029.0','1028.5','1028.0','1027.5','1027.0','1026.5','1026.0'),
                         gridcolor= 'rgb(125, 125, 125)', 
                              
                     
                        
               title_standoff = 40          

               ),
 )

#Change to trace amount
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)


# Change to years specific to data useing
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2015-01-01',
            y0=0,
            x1='2015-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2016-01-01',
            y0=0,
            x1='2016-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2017-01-01',
            y0=0,
            x1='2017-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2018-01-01',
            y0=0,
            x1='2018-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2019-01-01',
            y0=0,
            x1='2019-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))



# Adds rectangle around plot, change values specific to your data

fig.add_shape(
        # unfilled Rectangle
            type="rect",
            x0='2014-09-12',
            y0=1026.54,
            x1='2019-08-09',
            y1=1029.47,
            line=dict(
                 color="rgb(100, 100, 100)",
                 width=6.5
            ),)


# Makes legend item size larger
fig.update_layout(legend= {'itemsizing': 'constant'})


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3385c115-7100-46ed-aafa-a97406b4e349" class="plotly-graph-div" style="height:500px; width:2000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3385c115-7100-46ed-aafa-a97406b4e349")) {
#                     Plotly.newPlot(
#                         '3385c115-7100-46ed-aafa-a97406b4e349',
# ...

# %%
# Salinity Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os
import plotly.io as pio

# Default template
pio.templates.default = "plotly"

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/A/Salinity_All_CTD_Flanking_Subsurface_A.csv')


#Lines to plot with
trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')
trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')
trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')



# Plot layout
layout = go.Layout(title={ 
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                   
                   # Change title for plot of intrest
                   title_text = 'FA Salinity vs Time',
                 plot_bgcolor='rgb(255, 255, 255)',                 
                      showlegend=True,
                     legend_orientation="h",
                   
                
                  font=dict(
                          family="Avenir, monospace",
                          size=22,
                         color="#000000"),
                         height=500,
                         width=2000,
                   

                 xaxis=dict(
                         # Change title for x variable of intrest
                         title_text = 'Date',
                         tickmode = 'array',
                         ticktext = ('O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A'), 
                         tickvals=('2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01'),    
                                     
                          gridcolor= 'rgb(125, 125, 125)',
                        
                     ),
                   
                 yaxis=dict(
                     title_text = 'A Practical Salinity (PSU)',
                        tickmode = 'array',    
                        range=[34.6, 35.2],
                        tickvals = ('34.6','34.7','34.8','34.9','35','35.1','35.2'),
                         gridcolor= 'rgb(125, 125, 125)', 
               title_standoff = 10
               )
 )

#Change to trace amount
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)


# Change to years specific to data useing
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2015-01-01',
            y0=0,
            x1='2015-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2016-01-01',
            y0=0,
            x1='2016-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2017-01-01',
            y0=0,
            x1='2017-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2018-01-01',
            y0=0,
            x1='2018-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))
fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0='2019-01-01',
            y0=0,
            x1='2019-01-01',
            y1=1030,
             layer="below",
            line=dict(
                color="rgb(125, 125, 125)",
                width=5)
            
        ))



# Adds rectangle around plot, change values specific to your data

fig.add_shape(
        # unfilled Rectangle
            type="rect",
            x0='2014-09-12',
            y0=34.605,
            x1='2019-08-09',
            y1=35.195,
            line=dict(
                 color="rgb(100, 100, 100)",
                 width=6.5
            ),)


# Makes legend item size larger
fig.update_layout(legend= {'itemsizing': 'constant'})


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8a267fff-badb-4e99-b6d6-dbfc05ece6d4" class="plotly-graph-div" style="height:500px; width:2000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a267fff-badb-4e99-b6d6-dbfc05ece6d4")) {
#                     Plotly.newPlot(
#                         '8a267fff-badb-4e99-b6d6-dbfc05ece6d4',
# ...

# %%
# Temprature Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/surface/Temp_All_CTD_surface.csv')


trace1 = go.Scatter(x=df['Date'], y=df['12m'],  name='12m')


trace2 = go.Scatter(x=df['Date'], y=df['20m'],  name='20m')

trace3 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['100m'],  name='100m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'Surface Temp°C',
                        range=[2, 11],
                        dtick = 3,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6875af7f-d853-45d8-9c01-2a8257e92811" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6875af7f-d853-45d8-9c01-2a8257e92811")) {
#                     Plotly.newPlot(
#                         '6875af7f-d853-45d8-9c01-2a8257e92811',
# ...

# %%
# Salinity Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/surface/Salinity_All_CTD_surface .csv')


trace1 = go.Scatter(x=df['Date'], y=df['12m'],  name='12m')


trace2 = go.Scatter(x=df['Date'], y=df['20m'],  name='20m')

trace3 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['100m'],  name='100m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'Surface Salinity',
                        range=[34.6, 35.2],
                        dtick = 1,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="86b06ab9-6ebf-4186-a2f8-df7349c564bf" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86b06ab9-6ebf-4186-a2f8-df7349c564bf")) {
#                     Plotly.newPlot(
#                         '86b06ab9-6ebf-4186-a2f8-df7349c564bf',
# ...

# %%
# Density Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/surface/Denisty_All_CTD_surface.csv')


trace1 = go.Scatter(x=df['Date'], y=df['12m'],  name='12m')


trace2 = go.Scatter(x=df['Date'], y=df['20m'],  name='20m')

trace3 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['100m'],  name='100m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'Surface Density',
                     autorange = "reversed",
                        range=[1026.5,1029.5],
                        dtick = 1,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="17db5bc4-e3d2-4460-90f5-e6ea36c58587" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("17db5bc4-e3d2-4460-90f5-e6ea36c58587")) {
#                     Plotly.newPlot(
#                         '17db5bc4-e3d2-4460-90f5-e6ea36c58587',
# ...

# %%
# Temprature Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/B/Temp_All_CTD_Flanking_Subsurface_B.csv')


trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')


trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')

trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'B Temp°C',
                        range=[2, 11],
                        dtick = 3,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a37d516a-fc4e-4e4f-866d-c71583376103" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a37d516a-fc4e-4e4f-866d-c71583376103")) {
#                     Plotly.newPlot(
#                         'a37d516a-fc4e-4e4f-866d-c71583376103',
# ...

# %%
# Salinity Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/B/Salinity_All_CTD_Flanking_Subsurface_B.csv')


trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')


trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')

trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'B Salinity',
                        range=[34.6, 35.2],
                        dtick = 1,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="95f20282-3969-45d0-9379-b700ea4bc3e3" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95f20282-3969-45d0-9379-b700ea4bc3e3")) {
#                     Plotly.newPlot(
#                         '95f20282-3969-45d0-9379-b700ea4bc3e3',
# ...

# %%
# Density Plot
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/B/Density_All_CTD_Flanking_Subsurface_B.csv')


trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')


trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')

trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'B Density',
                     autorange = "reversed",
                        range=[1026.5,1029.5 ],
                        dtick = 1,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43660e18-8454-4ccb-aa70-c66dad0bd572" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43660e18-8454-4ccb-aa70-c66dad0bd572")) {
#                     Plotly.newPlot(
#                         '43660e18-8454-4ccb-aa70-c66dad0bd572',
# ...

# %%
# Heatflx
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/meteo data/SB11_Fulx.csv')


trace1 = go.Scatter(x=df['Date'], y=df['met_heatflx'],)



layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=False,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         range = [dt.date(2014, 9, 1), dt.date(2019, 9, 1)],
                        tickformat = '%b',
                       nticks = 60,
                     ),
                   
                 yaxis=dict(
                     title_text = 'SB11 HeatFlx',
                        range=[-300,600],
                        dtick = 200,
               title_standoff = 10
               )
 )

fig = go.Figure(data=[trace1], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="29a175d6-d9e1-4510-9e0b-4efc376f83c3" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("29a175d6-d9e1-4510-9e0b-4efc376f83c3")) {
#                     Plotly.newPlot(
#                         '29a175d6-d9e1-4510-9e0b-4efc376f83c3',
# ...

# %%
# Heatflx
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Irminger_2020_Project_Colab_Notebooks/Apex_Array/Ready to Graph/meteo data/SB12_Variables.csv')


trace1 = go.Scatter(x=df['Date'], y=df['30m'],  name='30m')


trace2 = go.Scatter(x=df['Date'], y=df['40m'],  name='40m')

trace3 = go.Scatter(x=df['Date'], y=df['60m'],  name='60m')
#surface
trace4 = go.Scatter(x=df['Date'], y=df['90m'],  name='90m')
#surface
trace5 = go.Scatter(x=df['Date'], y=df['130m'],  name='130m')
#surface
trace6 = go.Scatter(x=df['Date'], y=df['180m'],  name='180m')

trace7 = go.Scatter(x=df['Date'], y=df['250m'],  name='250m')




layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend=True,
                     legend_orientation="h",
                  font=dict(
                          family="Avenir, monospace",
                          size=28,
                         color="#000000"),
                         height=700,
                         width=1600,
                     xaxis=dict(
                         tickmode = 'linear',
                         dtick = 365,
                         tickformat = ' %B<br>%Y',
                     ),
                   
                 yaxis=dict(
                     title_text = 'SB12 HeatFlx',
                     autorange = "reversed",
                        range=[1026.5,1029.5 ],
                        dtick = 1,
               title_standoff = 40
               )
 )

fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7], layout=layout)
fig.show()

# %%
# Temprature Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
import os

if not os.path.exists("images"):
    os.mkdir("images")


df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['sea_surface_temperature'],  mode='lines', name='SST')
'''
Sea Surface Temperature is the temperature of the seawater near the ocean surface.
'''
trace1 = go.Scatter(x=df['Date'], y=df['air_temperature'],  name='AT')
'''
Air Temperature refers to the temperature of the air surrounding the sensor; this is also referred to as bulk temperature.
'''
trace2 = go.Scatter(x=df['Date'], y=df['met_tempa2m'], name='2m Temp')
'''
Air Temperature at 2 meters refers to the temperature of the air adjusted to a standard height of 2-meters above the sea surface; this is also referred to as bulk temperature.
'''

trace3 = go.Scatter(x=df['Date'], y=df['met_tempskn'], name='Skin Temp')
'''
the skin sea temperature based on the warmlayer and coolskin (coare35vn) model: metadata product TEMPSKN_L2.
'''

layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                   
                      showlegend= False,
    
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
            xaxis=dict(
                         range = [dt.date(2014, 6, 1), dt.date(2019, 1, 1)],
                         tickformat = ' %B<br>%Y',
                         nticks = 5,
                       
                     ),


                 yaxis=dict(
                     title_text = 'Temp°C',
                        range=[-10, 12],
               title_standoff = 0,
                      nticks = 3,
                  
               ),
                   
 )

fig = go.Figure(data=[trace, trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="94bb9b63-f668-4f9b-9a5a-d27a066d5b98" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94bb9b63-f668-4f9b-9a5a-d27a066d5b98")) {
#                     Plotly.newPlot(
#                         '94bb9b63-f668-4f9b-9a5a-d27a066d5b98',
# ...

# %%
# Temprature Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux2018.csv')

trace = go.Scatter( x=df['Date'], y=df['sea_surface_temperature'],  mode='lines', name='SST')
'''
Sea Surface Temperature is the temperature of the seawater near the ocean surface.
'''
trace1 = go.Scatter(x=df['Date'], y=df['air_temperature'],  name='AT')
'''
Air Temperature refers to the temperature of the air surrounding the sensor; this is also referred to as bulk temperature.
'''
trace2 = go.Scatter(x=df['Date'], y=df['met_tempa2m'], name='2m Temp')
'''
Air Temperature at 2 meters refers to the temperature of the air adjusted to a standard height of 2-meters above the sea surface; this is also referred to as bulk temperature.
'''

trace3 = go.Scatter(x=df['Date'], y=df['met_tempskn'], name='Skin Temp')
'''
the skin sea temperature based on the warmlayer and coolskin (coare35vn) model: metadata product TEMPSKN_L2.
'''

layout = go.Layout(title={
                           'y':0.92,
                           'x':0.18,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                  yaxis_title={'text':'Temp°C', 
                  },
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                    xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                     ),
                      yaxis=dict(
                     title_text = 'Temp°C',
                        range=[-10, 12],
               title_standoff = 0,
                      nticks = 3,
                  
               ),
 )

fig = go.Figure(data=[trace, trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f43b8e9-7bbb-4edb-a562-a11738a33c15" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f43b8e9-7bbb-4edb-a562-a11738a33c15")) {
#                     Plotly.newPlot(
#                         '1f43b8e9-7bbb-4edb-a562-a11738a33c15',
# ...

# %%
#Wind Speed Plots
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['met_relwind_speed'],  mode='lines', name='toga-coare Wind Speed')
'''met_relwind_speed: RELWIND_SPD-AUX, the magnitude of the vector difference of surface current (from VELPT measurements) from wind velocity (from METBK measurements). 
This is the fundamental windspeed variable used in the METBK toga-coare algorithms. 
It is anticipated that the wind measurements will be roughly each minute and that the current measurements will be broadcast to that resolution.
'''
trace1 = go.Scatter(x=df['Date'], y=df['met_wind10m'],  name='10m Wind Speed')
'''
Wind Velocity at 10 m is the speed and direction of air flowing across the ocean, adjusted to a standard height of 10 meters above the sea surface. This metric is also known as U10.
'''
layout = go.Layout(title={
                           'y':0.91,
                           'x':0.15,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   xaxis=dict(
                         range = [dt.date(2014, 6, 1), dt.date(2019, 1, 1)],
                         tickformat = ' %B<br>%Y',
                         nticks = 5,
                       
                     ),

                    yaxis=dict(
                        range=[0, 20],
                           title_text = 'm/s\N{SUPERSCRIPT TWO}',
                           title_standoff = 30,
                           nticks = 3,
                         
                           )
 )

fig = go.Figure(data=[trace, trace1], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b0cb04e-bcc8-4570-8f35-44fd89fcf624" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b0cb04e-bcc8-4570-8f35-44fd89fcf624")) {
#                     Plotly.newPlot(
#                         '1b0cb04e-bcc8-4570-8f35-44fd89fcf624',
# ...

# %%
#Wind Speed Plots
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux2018.csv')

trace = go.Scatter( x=df['Date'], y=df['met_relwind_speed'],  mode='lines', name='toga-coare Wind Speed')
'''met_relwind_speed: RELWIND_SPD-AUX, the magnitude of the vector difference of surface current (from VELPT measurements) from wind velocity (from METBK measurements). 
This is the fundamental windspeed variable used in the METBK toga-coare algorithms. 
It is anticipated that the wind measurements will be roughly each minute and that the current measurements will be broadcast to that resolution.
'''
trace1 = go.Scatter(x=df['Date'], y=df['met_wind10m'],  name='10m Wind Speed')
'''
Wind Velocity at 10 m is the speed and direction of air flowing across the ocean, adjusted to a standard height of 10 meters above the sea surface. This metric is also known as U10.
'''
layout = go.Layout(title={
                           'y':0.91,
                           'x':0.15,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                           family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
                       xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                     ),
                   
                   yaxis=dict(
                        range=[0, 20],
                           title_text = 'm/s\N{SUPERSCRIPT TWO}',
                           title_standoff = 30,
                           nticks = 3,
                         
                           )
 )

fig = go.Figure(data=[trace, trace1], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44097850-04d3-4c03-91ce-2d9c8c24e145" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44097850-04d3-4c03-91ce-2d9c8c24e145")) {
#                     Plotly.newPlot(
#                         '44097850-04d3-4c03-91ce-2d9c8c24e145',
# ...

# %%
#Specific Humidty Plots
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['met_sphum2m'],  mode='lines', name='2m specific humidity')
'''
Calculates the modelled specific humidity at a reference height of 2m SPHUM2M_L2.
'''
#trace1 = go.Scatter(x=df['Date'], y=df['met_wind10m'],  name='10m Wind Speed')
'''
Calculates SPECHUM_L2, the OOI air specific humidity core data product, for the METBK instrument. Not to be confused with the SPHUM2M_L2 data product.
'''
layout = go.Layout(title={
                          'y':0.91,
                           'x':0.08,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                           family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
                   xaxis=dict(
                         range = [dt.date(2014, 6, 1), dt.date(2019, 1, 1)],
                         tickformat = ' %B<br>%Y',
                         nticks = 5,
                       
                     ),

                    yaxis=dict(
                        range=[0, 10],
                           title_text = 'g/kg',
                           title_standoff = 30,
                           nticks = 3,
                           )
 )


fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16ef0425-0fe3-4e21-b8d8-f0d68c4c0f24" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16ef0425-0fe3-4e21-b8d8-f0d68c4c0f24")) {
#                     Plotly.newPlot(
#                         '16ef0425-0fe3-4e21-b8d8-f0d68c4c0f24',
# ...

# %%
#Specific Humidty Plots
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux2018.csv')

trace = go.Scatter( x=df['Date'], y=df['met_sphum2m'],  mode='lines', name='2m specific humidity')
'''
Calculates the modelled specific humidity at a reference height of 2m SPHUM2M_L2.
'''
#trace1 = go.Scatter(x=df['Date'], y=df['met_wind10m'],  name='10m Wind Speed')
'''
Calculates SPECHUM_L2, the OOI air specific humidity core data product, for the METBK instrument. Not to be confused with the SPHUM2M_L2 data product.
'''
layout = go.Layout(title={
                          'y':0.91,
                           'x':0.08,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
          font=dict(
                           family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
                   xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                     ),
                   
                    
                    yaxis=dict(
                        range=[0, 10],
                           title_text = 'g/kg',
                           title_standoff = 30,
                           nticks = 3,
                           )
 )

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="af5aa42c-65e1-488f-b08b-6c89807c35e2" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af5aa42c-65e1-488f-b08b-6c89807c35e2")) {
#                     Plotly.newPlot(
#                         'af5aa42c-65e1-488f-b08b-6c89807c35e2',
# ...

# %%
# Latent Sensible Longwave Shortwave Flux Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['met_latnflx'],  mode='lines', name='Latent')
'''
the upward latent heat flux data product LATNFLX_L2.
'''
trace1 = go.Scatter(x=df['Date'], y=df['met_sensflx'],  name='Sensible')
'''
The net upward sensible heat flux SENSFLX_L2.
'''
trace2 = go.Scatter(x=df['Date'], y=df['met_netlirr'], name='-Longwave')
'''
The net upward longwave irradiance NETLIRR_L2.
'''

trace3 = go.Scatter(x=df['Date'], y=df['met_netsirr_hourly'], name='Shortwave')
'''
 the OOI core data product net shortwave radiation in the downward direction, for the METBK instrument.
'''

layout = go.Layout(title={
                           'y':0.91,
                           'x':0.221,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                           
                   xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                     ),
                     
                    yaxis=dict(
                        range=[-399.9, 399.9],
                        title_text = 'W/m\N{SUPERSCRIPT TWO}',
                        title_standoff = 0,
                        nticks = 4,
                            
                           )
 )

fig = go.Figure(data=[trace, trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="08d802ad-2357-43a7-8d0c-46e0ce149e46" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08d802ad-2357-43a7-8d0c-46e0ce149e46")) {
#                     Plotly.newPlot(
#                         '08d802ad-2357-43a7-8d0c-46e0ce149e46',
# ...

# %%
# Latent Sensible Longwave Shortwave Flux Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import datetime as dt
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux2018.csv')

trace = go.Scatter( x=df['Date'], y=df['met_latnflx'],  mode='lines', name='Latent')
'''
the upward latent heat flux data product LATNFLX_L2.
'''
trace1 = go.Scatter(x=df['Date'], y=df['met_sensflx'],  name='Sensible')
'''
The net upward sensible heat flux SENSFLX_L2.
'''
trace2 = go.Scatter(x=df['Date'], y=df['met_netlirr'], name='Longwave')
'''
The net upward longwave irradiance NETLIRR_L2.
'''

trace3 = go.Scatter(x=df['Date'], y=df['met_netsirr_hourly'], name='Shortwave')
'''
 the OOI core data product net shortwave radiation in the downward direction, for the METBK instrument.
'''

layout = go.Layout(title={
                           'y':0.91,
                           'x':0.221,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                         
                         family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
                    xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                     ),
                yaxis=dict(
                        range=[-399.9, 399.9],
                        title_text = 'W/m\N{SUPERSCRIPT TWO}',
                        title_standoff = 0,
                        nticks = 4,
                            
                           )
 )
 

fig = go.Figure(data=[trace, trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b7ce8c2d-2db8-41e5-8075-1c0407b88bf3" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b7ce8c2d-2db8-41e5-8075-1c0407b88bf3")) {
#                     Plotly.newPlot(
#                         'b7ce8c2d-2db8-41e5-8075-1c0407b88bf3',
# ...

# %%
# Net Heat Flux Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['met_heatflx'],  mode='lines', name='Net Heat Flux')
'''
The total net upward heat flux data product HEATFLX_L2.
'''

layout = go.Layout(title={
                           'y':0.91,
                           'x':0.065,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                   
                         xaxis=dict(
                             range = [dt.date(2014, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 5,
                         
                         ),
                     
                    yaxis=dict(
                        range=[-900, 500],
                           title_text = 'W/m\N{SUPERSCRIPT TWO}',
                           title_standoff = 0,
                            nticks = 3,
                           )
 )

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="19feb936-e1ca-42b8-aeb6-5d38431dbf1a" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19feb936-e1ca-42b8-aeb6-5d38431dbf1a")) {
#                     Plotly.newPlot(
#                         '19feb936-e1ca-42b8-aeb6-5d38431dbf1a',
# ...

# %%
# Net Heat Flux Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux2018.csv')

trace = go.Scatter( x=df['Date'], y=df['met_heatflx'],  mode='lines', name='Net Heat Flux')
'''
The total net upward heat flux data product HEATFLX_L2.
'''

layout = go.Layout(title={
                           'y':0.91,
                           'x':0.065,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                    xaxis=dict(
                      range = [dt.date(2018, 6, 1), dt.date(2019, 1, 1)],
                        tickformat = ' %B<br>%Y',
                       nticks = 3,
                       
                    ),

                    yaxis=dict(
                        range=[-500, 500],
                           title_text = 'W/m\N{SUPERSCRIPT TWO}',
                           title_standoff = 0,
                           nticks = 3,
                           
                           )
 )

fig = go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="540b2262-0d8d-42eb-b8e4-7cb05f4c71d6" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("540b2262-0d8d-42eb-b8e4-7cb05f4c71d6")) {
#                     Plotly.newPlot(
#                         '540b2262-0d8d-42eb-b8e4-7cb05f4c71d6',
# ...

# %%
# Cumulative Lat & Sen Flux Plot
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd


fig = go.Figure()

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/finalheatfxmaster.csv')

fig.add_trace(go.Scatter(x=df['Date'], y=df['cLat14-15'], line = dict(color='royalblue', dash='line', name= '14-15 Lat')))

fig.add_trace(go.Scatter((x=df['Date'], y=df['cLat15-16'], line = dict(color='royalblue', dash='dash', name= '15-16 Lat')))

fig.add_trace(go.Scatter((x=df['Date'], y=df['cLat18-19'], line = dict(color='royalblue', dash='dot', name= '18-19 Lat')))


fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens14-15']))

fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens15-16']))

fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens18-19']))


fig.update_layout(title={'text':'k) Cumulative Lat & Sen Flux',
                           'y':0.93,
                           'x':0.111,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                  yaxis_title={'text':'Temp°C', 
                  },
                  font=dict(
                          family="Avenir, monospace",
                          size=24,
                         color="#000000"),
                         height=700,
                         width=3600,
                    yaxis=dict(
                        range=[-2, 0.5]
                            )
 )

fig = go.Figure(data=[trace, trace1, trace2, trace3, trace4, trace5], layout=layout)
fig.show()
# Out:
#   File "<ipython-input-61-d58ca7939072>", line 14
#     fig.add_trace(go.Scatter((x=df['Date'], y=df['cLat15-16'], line = dict(color='royalblue', dash='dash', name= '15-16 Lat')))
#                                ^
# SyntaxError: invalid syntax

# %%
import plotly.graph_objects as go

# Add data

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/finalheatfxmaster.csv')

fig = go.Figure()
# Create and style traces
fig.add_trace(go.Scatter(x=df['Date'], y=df['cLat14-15'],name= '14-15 Lat',
                         line=dict(color='red')))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cLat15-16'],name= '15-16 Lat',
                         line=dict(color='firebrick', dash='dot', width = 5)))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cLat18-19'],name= '18-19 Lat',
                         line=dict(color='mediumvioletred', dash='dash', width = 4)))


fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens14-15'],name= '14-15 Sens',
                         line=dict(color='blue')))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens15-16'],name= '15-16 Sens',
                         line=dict(color='royalblue', dash='dot',width = 5)))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cSens18-19'],name= '18-19 Sens',
                         line=dict(color='midnightblue', dash='dash',width = 4)))
# Edit the layout
fig.update_layout(title={
                           'y':0.93,
                           'x':0.149,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                  legend_orientation="h",
                  showlegend=True,
                  yaxis_title={'text':'Flux (J/m\N{SUPERSCRIPT TWO})', 
                  },
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                  xaxis=dict(
                       tickformat = ' %B<br>%Y',
                         tickmode = 'linear',
                         dtick = 55
                         ),
                    yaxis=dict(
                      range=[-2.4, 0.4],
                      title_standoff = 30,
                           nticks = 3,
                       )  
                   
                            
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cfaee319-d568-49d7-aba7-27fe35e9c362" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cfaee319-d568-49d7-aba7-27fe35e9c362")) {
#                     Plotly.newPlot(
#                         'cfaee319-d568-49d7-aba7-27fe35e9c362',
# ...

# %%
import plotly.graph_objects as go

# Add data

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/finalheatfxmaster.csv')

fig = go.Figure()
# Create and style traces
fig.add_trace(go.Scatter(x=df['Date'], y=df['cHt14-15'], name ='14-15 HeatFX',
                         line=dict(color='red')))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cHt15-16'], name ='15-16 HeatFX',
                         line=dict(color='firebrick', dash='dot',width = 5,)))
fig.add_trace(go.Scatter(x=df['Date'], y=df['cHt18-19'], name ='18-19 HeatFX',
                         line=dict(color='mediumvioletred', dash='dash', width = 6 )))

# Edit the layout
fig.update_layout(title={
                           'y':0.93,
                           'x':0.131,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                  
                  yaxis_title={'text':'Flux (J/m\N{SUPERSCRIPT TWO})', 
                  },
                  font=dict(
                          family="Avenir, monospace",
                          size=48,
                         color="#000000"),
                         height=700,
                         width=1600,
                  xaxis=dict(
                      
                           tickformat = ' %B<br>%Y',
                         tickmode = 'linear',
                         dtick = 55
                         ),
                    yaxis=dict(
                       range=[-2.4, 0.4],
                        nticks = 3,
                       )  
                   
                            
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd68b40b-beeb-461f-a3e0-6ca02b21af53" class="plotly-graph-div" style="height:700px; width:1600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd68b40b-beeb-461f-a3e0-6ca02b21af53")) {
#                     Plotly.newPlot(
#                         'cd68b40b-beeb-461f-a3e0-6ca02b21af53',
# ...

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')

trace = go.Scatter( x=df['Date'], y=df['met_latnflx'],  mode='lines', name='Latent')
'''
the upward latent heat flux data product LATNFLX_L2.
'''
trace1 = go.Scatter(x=df['Date'], y=df['met_sensflx'],  name='Sensible')
'''
The net upward sensible heat flux SENSFLX_L2.
'''
trace2 = go.Scatter(x=df['Date'], y=df['met_netlirr'], name='Longwave')
'''
The net upward longwave irradiance NETLIRR_L2.
'''

trace3 = go.Scatter(x=df['Date'], y=df['met_netsirr_hourly'], name='Shortwave')
'''
 the OOI core data product net shortwave radiation in the downward direction, for the METBK instrument.
'''

layout = go.Layout(title={'text':'g) Heat Flux: Latent(Blue), Sensible(Red), Longwave(Green), Shortwave(Purple) ',
                           'y':0.91,
                           'x':0.221,
                           'xanchor': 'center',
                           'yanchor': 'top'}, 
                  plot_bgcolor='rgb(230, 230,230)',
                  paper_bgcolor='rgb(255, 255, 255)',
                
                  showlegend=False,
                
                  font=dict(
                          family="Avenir, monospace",
                          size=24,
                         color="#000000"),
                         height=700,
                         width=3600,
                    yaxis=dict(
                        range=[-350, 350],
                           title_text = 'W/m\N{SUPERSCRIPT TWO}',
                           title_standoff = 0,
                           )
 )

fig = go.Figure(data=[trace, trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d79f35c9e018> in <module>()
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')
#       7
#       8 trace = go.Scatter( x=df['Date'], y=df['met_latnflx'],  mode='lines', name='Latent')
#
# ...

# %%
# !pip install  dash
# Out:
# ...
#      |████████████████████████████████| 71kB 2.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 8.0MB/s
# ...
#      |████████████████████████████████| 3.3MB 49.4MB/s
# ...
#      |████████████████████████████████| 194kB 49.0MB/s
# ...
#      |████████████████████████████████| 1.8MB 30.9MB/s
# ...
#   Created wheel for dash: filename=dash-1.9.0-cp36-none-any.whl size=71493 sha256=d21b0169f7c692c3534f94f96f0badb9968a07d01797205477171888e9c2bddc
#   Stored in directory: /root/.cache/pip/wheels/7e/7e/fc/054fe8c699e44542afd4b301486bf48443adef4f591ab92818
# ...
#   Created wheel for flask-compress: filename=Flask_Compress-1.4.0-cp36-none-any.whl size=3712 sha256=7806eee47348e075b967f1e8a42169d97180bf31190b847955c78228e8fa52f8
#   Stored in directory: /root/.cache/pip/wheels/96/32/88/a1f6d9dd3c29570ab3a8acc0d556b3b20abcf3c623c868ce0a
# ...
#   Created wheel for dash-renderer: filename=dash_renderer-1.2.4-cp36-none-any.whl size=1146887 sha256=1e8d295704cc6bba31adab95844b750bbf5187acde5e73e0948882cb59355a0e
# ...

# %%
# !pip install app
# Out:
# ...
#   Created wheel for app: filename=app-0.0.1-cp36-none-any.whl size=1519 sha256=861017d41612710b07cca1648be3cc0d3018e9280de13e38e6e9b9f23656112a
#   Stored in directory: /root/.cache/pip/wheels/9c/ab/d2/9a121974bb3f903f8d57e5fe98056d08d367e60e0c32e0f606
# Successfully built app
# ...

# %%
# !pip install init
# Out:
# ...
#   Created wheel for init: filename=init-0.1.0-cp36-none-any.whl size=36341 sha256=7c0aebaef00e8490844607cd33d6a81cac2f12fc00497c56d2ac695f8f654900
#   Stored in directory: /root/.cache/pip/wheels/5f/fa/81/b3fb590dfaec2e0423732bafd7b6992977f25d5c2d96923285
# ...
#   Created wheel for terminal: filename=terminal-0.4.0-cp36-none-any.whl size=13222 sha256=327022cdb449de6255df5db011f4d8eb44c4e198c7cd12ac20a3d347658d0f6d
#   Stored in directory: /root/.cache/pip/wheels/7e/ca/01/f96ebc47ba4074755bd8251b1bacfe688da11496a4b8394224
# Successfully built init terminal
# ...

# %%
pip install psutil requests

# %%
conda install orca
# Out:
#   File "<ipython-input-80-22aa1d3ebc91>", line 1
#     conda install orca
#                 ^
# SyntaxError: invalid syntax

# %%
import os

import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go

app = dash.Dash(__name__)

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/allflux.csv')
df["month"] = pd.DatetimeIndex(df["Date"]).month

if 'DYNO' in os.environ:
    app_name = os.environ['DASH_APP_NAME']
else:
    app_name = 'dash-plotfromcsvplot'

app.layout = html.Div([
    html.H1("a) SST, Air Temp, 2m Temp, Skin Temp", style={'textAlign': "center"}),
    html.Div([html.Div(dcc.Dropdown(id='value-selected',
                           options=[{'label': str(i).replace('-', ' '), 'value': i} for i in df.columns.values[2:9]],
                           value=["Number-transactions"],
                           multi=True,
                           style={"display": "block", "margin-left": "auto", "margin-right": "auto", "width": "80%"},
                           className="eight columns"),
              html.A("View the CSV dataset",
                     href="/content/drive/My Drive/Colab Notebooks/allflux.csv",
                     target="_blank", style={"width": "30%", "float": "right"}, className="four columns",
             className="row"),
    dcc.Graph(id="my-graph"),
    html.Div([dcc.RangeSlider(id='month-selected', min=1, max=12, step=1,
                              marks={1: "January", 2: "Febuary", 3: "March", 4: "April", 5: "May", 6: "June", 7: "July", 8: "August", 9: "September",
                                     10: "October"}, value=[1, 12])]), 
className="container")

@app.callback(
    dash.dependencies.Output("my-graph", "figure"),
    [dash.dependencies.Input("month-selected", "value"), dash.dependencies.Input("value-selected", "value")])
def update_graph(selected1, selected2):
    dff = df[(df["month"] >= selected1[0]) & (df["month"] <= selected1[1])]
    new_list = []
    for i in selected2:
        new_list.append((str(i).replace('-', ' ')))
    trace = []
    for indicator in selected2:
        trace.append(go.Scatter(x=dff.Date, y=dff[indicator], name=indicator, mode="lines",
                                marker={'size': 15, 'line': {'width': 0.5, 'color': 'white'}}, ))

    return {"data": trace, "layout": go.Layout(title=f"{','.join(new_list[0:-1])} and {''.join(new_list[-1])} vs Date",
                                               xaxis={"title": "Date"}, yaxis={"title": f"Value"},
                                               colorway=["#C7037A", "#E20048", "#FFCB00", "#FF7C00", "#2F9609",
                                                         "#0E4770", "#A8AE0B"])}
# Out:
#   File "<ipython-input-113-72946b76a781>", line 40
#     def update_graph(selected1, selected2):
#       ^
# SyntaxError: invalid syntax
